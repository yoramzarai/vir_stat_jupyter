# %% [markdown]
# # UR Correspondence between Hosts and Viruses
#
# Here we analyze the UR correspondance between hosts and viruses. The analyzed spreadsheet is
# cross_UR_m[val]_[rnd model].xlsx.
#
# ## Parsing the xlsx file

# %%
import pandas as pd
import os, sys
import re
import myseq_logo as mysl
import pald_funcs as mypal # my palindrome functions
from Bio import motifs, SeqIO
from Bio.Seq import Seq
import matplotlib.pyplot as plt
import UR_host_funcs as urh
from pprint import pprint
from collections import defaultdict


# MOVE THIS TO UTILITIES FUNCTIONS
def get_seq_count(seqs):
    '''This function returns a dictionary, where the keys are the (unique)
    sequences and the values are the number of occurances. Input seqs is a list
    of strings.'''
    from collections import defaultdict
    d = defaultdict(int)
    for s in seqs: d[s] += 1
    #sorted(d, key=d.get, reverse=True) # this returns a sorted list in descending order
    return d 



mlens = [3, 4, 5] #, 4] #, 4, 5)

vtypes = ('ssDNA', 'dsDNA', 'ssRNA', 'dsRNA')
htypes = ('Vertebrate', 'Bacteria', 'Fungi', 'Metazoa', 'Plants', 'Protists')
cross_type = ('v_h', 'v_nh', 'nv_h')
# =====================================================================================================
base_path = '/Users/yoramzarai/work/school/Simulation/Viruses/Data_stats/'
dtype_rnd = {'hst_db':str, 'hst_name':str, 'hst_taxid':int, 'vrs_taxid':int, \
             'vrs_type':str, 'UR_v_h':str, 'UR_v_nh':str, 'UR_nv_h':str, 'UR_nv_nh':str}
mmlens = ['m'+str(m) for m in mlens]


cross_d = defaultdict()
for j, mlen in enumerate(mlens):
    rnd_model = 'dnt_samp' if mlen==3 else 'syn_perm+dnt_samp'
    # VUR xslx file
    xlsx_file = os.path.join(base_path, 'cross_UR_'+mmlens[j]+'_'+rnd_model+'.xlsx')
    df_cross = pd.read_excel(xlsx_file, header=0, dtype=dtype_rnd)
    
    
    # different virus types
    print('\nVirus info:')
    for vtype in vtypes:
        df_type = df_cross.loc[df_cross['vrs_type']==vtype, :]
        for ctype in cross_type:
            ur = df_type.loc[:,'UR_'+ctype].apply(lambda x: x.split('|'))
            allurs = [x for i in ur for x in i if x!='nan']
            d_allurs = get_seq_count(allurs)
            srt_allurs = sorted(d_allurs, key=d_allurs.get, reverse=True)
            #print('m{}: {}: {}: {} URs/virus : (Top) {}'.format(mlen, vtype, ctype, len(allurs)/ur.size, srt_allurs[0:3]))
            #for k in srt_allurs: print('{}: {}'.format(k, d_allurs[k]))
    
    
    # different virus types
    print('\nHost info:')
    for htype in htypes:
        df_type = df_cross.loc[df_cross['hst_db']==htype, :]
        for ctype in cross_type:
            ur = df_type.loc[:,'UR_'+ctype].apply(lambda x: x.split('|'))
            allurs = [x for i in ur for x in i if x!='nan']
            d_allurs = get_seq_count(allurs)
            srt_allurs = sorted(d_allurs, key=d_allurs.get, reverse=True)
            #print('m{}: {}: {}: {} URs/host : (Top) {}'.format(mlen, htype, ctype, len(allurs)/ur.size, srt_allurs[0:3]))
    
    
    # host-virus types
    print('\nHost-Virus info:')
    for htype in htypes:
        df_type = df_cross.loc[df_cross['hst_db']==htype, :]
        for vtype in vtypes:
            df_type2 = df_type.loc[df_type['vrs_type']==vtype, :]
            #print(df_type2.head)
            for ctype in cross_type:
                ur = df_type2.loc[:,'UR_'+ctype].apply(lambda x: x.split('|'))
                allurs = [x for i in ur for x in i if x!='nan']
                d_allurs = get_seq_count(allurs) if allurs else {}
                cross_d[':'.join([mmlens[j], htype, vtype, ctype, str(ur.size)])] = d_allurs  # saving for post processing
                if d_allurs:
                    srt_allurs = sorted(d_allurs, key=d_allurs.get, reverse=True)
                    #print('{}:{}:{}:{}:{} {} URs/virus : (Top) {}'.format(mmlens[j], htype, vtype, ctype, str(ur.size), len(allurs)/ur.size, srt_allurs[0:3]))
# Out:
# Virus info:
#
# Host info:
#
# Host-Virus info:
#
# Virus info:
#
# Host info:
#
# Host-Virus info:
#
# Virus info:
#
# Host info:
#
# Host-Virus info:

# %% [markdown]
# ## Processing the correspondance

# %%
# MAKE SURE THE CELL ABOVE RUNS FIRST !!

from pprint import pprint
print(len(cross_d))
for k, v in cross_d.items():
    srt = sorted(v, key=v.get, reverse=True)
    mm, hh, vv, cc, nn = tuple(k.split(':'))
    print(mm, hh, vv, cc, nn, sep=',')
    #print(k, end=':\n')
    for x in srt: print('\t{}: {}'.format(x, v[x]))
# Out:
# 216
# m3,Vertebrate,ssDNA,v_h,128
# m3,Vertebrate,ssDNA,v_nh,128
# m3,Vertebrate,ssDNA,nv_h,128
# m3,Vertebrate,dsDNA,v_h,207
# m3,Vertebrate,dsDNA,v_nh,207
# m3,Vertebrate,dsDNA,nv_h,207
# m3,Vertebrate,ssRNA,v_h,354
# m3,Vertebrate,ssRNA,v_nh,354
# m3,Vertebrate,ssRNA,nv_h,354
# m3,Vertebrate,dsRNA,v_h,34
# m3,Vertebrate,dsRNA,v_nh,34
# m3,Vertebrate,dsRNA,nv_h,34
# m3,Bacteria,ssDNA,v_h,49
# m3,Bacteria,ssDNA,v_nh,49
# m3,Bacteria,ssDNA,nv_h,49
# m3,Bacteria,dsDNA,v_h,1384
# m3,Bacteria,dsDNA,v_nh,1384
# m3,Bacteria,dsDNA,nv_h,1384
# m3,Bacteria,ssRNA,v_h,15
# m3,Bacteria,ssRNA,v_nh,15
# m3,Bacteria,ssRNA,nv_h,15
# m3,Bacteria,dsRNA,v_h,6
# m3,Bacteria,dsRNA,v_nh,6
# m3,Bacteria,dsRNA,nv_h,6
# m3,Fungi,ssDNA,v_h,1
# m3,Fungi,ssDNA,v_nh,1
# m3,Fungi,ssDNA,nv_h,1
# m3,Fungi,dsDNA,v_h,0
# m3,Fungi,dsDNA,v_nh,0
# m3,Fungi,dsDNA,nv_h,0
# m3,Fungi,ssRNA,v_h,7
# m3,Fungi,ssRNA,v_nh,7
# m3,Fungi,ssRNA,nv_h,7
# m3,Fungi,dsRNA,v_h,18
# m3,Fungi,dsRNA,v_nh,18
# m3,Fungi,dsRNA,nv_h,18
# m3,Metazoa,ssDNA,v_h,3
# m3,Metazoa,ssDNA,v_nh,3
# m3,Metazoa,ssDNA,nv_h,3
# m3,Metazoa,dsDNA,v_h,4
# m3,Metazoa,dsDNA,v_nh,4
# m3,Metazoa,dsDNA,nv_h,4
# m3,Metazoa,ssRNA,v_h,48
# m3,Metazoa,ssRNA,v_nh,48
# m3,Metazoa,ssRNA,nv_h,48
# m3,Metazoa,dsRNA,v_h,1
# m3,Metazoa,dsRNA,v_nh,1
# m3,Metazoa,dsRNA,nv_h,1
# m3,Plants,ssDNA,v_h,124
# m3,Plants,ssDNA,v_nh,124
# m3,Plants,ssDNA,nv_h,124
# m3,Plants,dsDNA,v_h,0
# m3,Plants,dsDNA,v_nh,0
# m3,Plants,dsDNA,nv_h,0
# m3,Plants,ssRNA,v_h,120
# m3,Plants,ssRNA,v_nh,120
# m3,Plants,ssRNA,nv_h,120
# m3,Plants,dsRNA,v_h,10
# m3,Plants,dsRNA,v_nh,10
# m3,Plants,dsRNA,nv_h,10
# m3,Protists,ssDNA,v_h,0
# m3,Protists,ssDNA,v_nh,0
# m3,Protists,ssDNA,nv_h,0
# m3,Protists,dsDNA,v_h,1
# m3,Protists,dsDNA,v_nh,1
# m3,Protists,dsDNA,nv_h,1
# m3,Protists,ssRNA,v_h,0
# m3,Protists,ssRNA,v_nh,0
# m3,Protists,ssRNA,nv_h,0
# m3,Protists,dsRNA,v_h,3
# m3,Protists,dsRNA,v_nh,3
# m3,Protists,dsRNA,nv_h,3
# m4,Vertebrate,ssDNA,v_h,128
# m4,Vertebrate,ssDNA,v_nh,128
# m4,Vertebrate,ssDNA,nv_h,128
# m4,Vertebrate,dsDNA,v_h,207
# m4,Vertebrate,dsDNA,v_nh,207
# m4,Vertebrate,dsDNA,nv_h,207
# m4,Vertebrate,ssRNA,v_h,354
# m4,Vertebrate,ssRNA,v_nh,354
# m4,Vertebrate,ssRNA,nv_h,354
# m4,Vertebrate,dsRNA,v_h,34
# m4,Vertebrate,dsRNA,v_nh,34
# m4,Vertebrate,dsRNA,nv_h,34
# m4,Bacteria,ssDNA,v_h,49
# m4,Bacteria,ssDNA,v_nh,49
# m4,Bacteria,ssDNA,nv_h,49
# m4,Bacteria,dsDNA,v_h,1384
# m4,Bacteria,dsDNA,v_nh,1384
# m4,Bacteria,dsDNA,nv_h,1384
# m4,Bacteria,ssRNA,v_h,15
# m4,Bacteria,ssRNA,v_nh,15
# m4,Bacteria,ssRNA,nv_h,15
# m4,Bacteria,dsRNA,v_h,6
# m4,Bacteria,dsRNA,v_nh,6
# m4,Bacteria,dsRNA,nv_h,6
# m4,Fungi,ssDNA,v_h,1
# m4,Fungi,ssDNA,v_nh,1
# m4,Fungi,ssDNA,nv_h,1
# m4,Fungi,dsDNA,v_h,0
# m4,Fungi,dsDNA,v_nh,0
# m4,Fungi,dsDNA,nv_h,0
# m4,Fungi,ssRNA,v_h,7
# m4,Fungi,ssRNA,v_nh,7
# m4,Fungi,ssRNA,nv_h,7
# m4,Fungi,dsRNA,v_h,18
# m4,Fungi,dsRNA,v_nh,18
# m4,Fungi,dsRNA,nv_h,18
# m4,Metazoa,ssDNA,v_h,3
# m4,Metazoa,ssDNA,v_nh,3
# m4,Metazoa,ssDNA,nv_h,3
# m4,Metazoa,dsDNA,v_h,4
# m4,Metazoa,dsDNA,v_nh,4
# m4,Metazoa,dsDNA,nv_h,4
# m4,Metazoa,ssRNA,v_h,48
# m4,Metazoa,ssRNA,v_nh,48
# m4,Metazoa,ssRNA,nv_h,48
# m4,Metazoa,dsRNA,v_h,1
# m4,Metazoa,dsRNA,v_nh,1
# m4,Metazoa,dsRNA,nv_h,1
# m4,Plants,ssDNA,v_h,124
# m4,Plants,ssDNA,v_nh,124
# m4,Plants,ssDNA,nv_h,124
# m4,Plants,dsDNA,v_h,0
# m4,Plants,dsDNA,v_nh,0
# m4,Plants,dsDNA,nv_h,0
# m4,Plants,ssRNA,v_h,120
# m4,Plants,ssRNA,v_nh,120
# m4,Plants,ssRNA,nv_h,120
# m4,Plants,dsRNA,v_h,10
# m4,Plants,dsRNA,v_nh,10
# m4,Plants,dsRNA,nv_h,10
# m4,Protists,ssDNA,v_h,0
# m4,Protists,ssDNA,v_nh,0
# m4,Protists,ssDNA,nv_h,0
# m4,Protists,dsDNA,v_h,1
# m4,Protists,dsDNA,v_nh,1
# m4,Protists,dsDNA,nv_h,1
# m4,Protists,ssRNA,v_h,0
# m4,Protists,ssRNA,v_nh,0
# m4,Protists,ssRNA,nv_h,0
# m4,Protists,dsRNA,v_h,3
# m4,Protists,dsRNA,v_nh,3
# m4,Protists,dsRNA,nv_h,3
# m5,Vertebrate,ssDNA,v_h,128
# m5,Vertebrate,ssDNA,v_nh,128
# m5,Vertebrate,ssDNA,nv_h,128
# m5,Vertebrate,dsDNA,v_h,207
# m5,Vertebrate,dsDNA,v_nh,207
# m5,Vertebrate,dsDNA,nv_h,207
# m5,Vertebrate,ssRNA,v_h,354
# m5,Vertebrate,ssRNA,v_nh,354
# m5,Vertebrate,ssRNA,nv_h,354
# m5,Vertebrate,dsRNA,v_h,34
# m5,Vertebrate,dsRNA,v_nh,34
# m5,Vertebrate,dsRNA,nv_h,34
# m5,Bacteria,ssDNA,v_h,49
# m5,Bacteria,ssDNA,v_nh,49
# m5,Bacteria,ssDNA,nv_h,49
# m5,Bacteria,dsDNA,v_h,1384
# m5,Bacteria,dsDNA,v_nh,1384
# m5,Bacteria,dsDNA,nv_h,1384
# m5,Bacteria,ssRNA,v_h,15
# m5,Bacteria,ssRNA,v_nh,15
# m5,Bacteria,ssRNA,nv_h,15
# m5,Bacteria,dsRNA,v_h,6
# m5,Bacteria,dsRNA,v_nh,6
# m5,Bacteria,dsRNA,nv_h,6
# m5,Fungi,ssDNA,v_h,1
# m5,Fungi,ssDNA,v_nh,1
# m5,Fungi,ssDNA,nv_h,1
# m5,Fungi,dsDNA,v_h,0
# m5,Fungi,dsDNA,v_nh,0
# m5,Fungi,dsDNA,nv_h,0
# m5,Fungi,ssRNA,v_h,7
# m5,Fungi,ssRNA,v_nh,7
# m5,Fungi,ssRNA,nv_h,7
# m5,Fungi,dsRNA,v_h,18
# m5,Fungi,dsRNA,v_nh,18
# m5,Fungi,dsRNA,nv_h,18
# m5,Metazoa,ssDNA,v_h,3
# m5,Metazoa,ssDNA,v_nh,3
# m5,Metazoa,ssDNA,nv_h,3
# m5,Metazoa,dsDNA,v_h,4
# m5,Metazoa,dsDNA,v_nh,4
# m5,Metazoa,dsDNA,nv_h,4
# m5,Metazoa,ssRNA,v_h,48
# m5,Metazoa,ssRNA,v_nh,48
# m5,Metazoa,ssRNA,nv_h,48
# m5,Metazoa,dsRNA,v_h,1
# m5,Metazoa,dsRNA,v_nh,1
# m5,Metazoa,dsRNA,nv_h,1
# m5,Plants,ssDNA,v_h,124
# m5,Plants,ssDNA,v_nh,124
# m5,Plants,ssDNA,nv_h,124
# m5,Plants,dsDNA,v_h,0
# m5,Plants,dsDNA,v_nh,0
# m5,Plants,dsDNA,nv_h,0
# m5,Plants,ssRNA,v_h,120
# m5,Plants,ssRNA,v_nh,120
# m5,Plants,ssRNA,nv_h,120
# m5,Plants,dsRNA,v_h,10
# m5,Plants,dsRNA,v_nh,10
# m5,Plants,dsRNA,nv_h,10
# m5,Protists,ssDNA,v_h,0
# m5,Protists,ssDNA,v_nh,0
# m5,Protists,ssDNA,nv_h,0
# m5,Protists,dsDNA,v_h,1
# m5,Protists,dsDNA,v_nh,1
# m5,Protists,dsDNA,nv_h,1
# m5,Protists,ssRNA,v_h,0
# m5,Protists,ssRNA,v_nh,0
# m5,Protists,ssRNA,nv_h,0
# m5,Protists,dsRNA,v_h,3
# m5,Protists,dsRNA,v_nh,3
# m5,Protists,dsRNA,nv_h,3

# %% [markdown]
# # Scratch Pad

# %%
 # all dsDNA
df_type = df_cross.loc[df_cross['vrs_type']=='Retro-transcribing', :]
df_type1 = df_type.loc[df_type['hst_db']=='Plants']  # all Plants with Retro- viruses
#print(df_type1)
#ur = df_type.loc[:,'UR_nv_h'].apply(lambda x:x.split('|'))
#print(ur.iloc[0])
#allurs = [x for i in ur for x in i if x!='nan']
#print(ur.index[0])
#print(allurs, len(allurs), ur.shape[0], len(allurs)/ur.size)
    
xx = ['AAA', 'AAB', 'AAC', 'AAA', 'AAA', 'AAB', 'KKK', 'AAA', 'KKK']
pprint(get_seq_count(xx))
    
ss = ':'.join(['a', 'b', 'c'])
print(ss)
