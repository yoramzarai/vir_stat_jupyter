# %% [markdown]
# # Virus UR clusters logos

# %%
import pandas as pd
import os, sys
import re
from Bio import motifs, SeqIO
from Bio.Seq import Seq
import matplotlib.pyplot as plt
from collections import OrderedDict
import subprocess
from pprint import pprint

import mysequtils as myut
import myseqclusters as mycl
import myseq_logo as mysl
import pald_funcs as mypal # my palindrome functions


mlens = [3, 4, 5]
num_tst_vtaxids = 10 # the number of vtaxids with the most common UR to process
clst_path = './clust_data'
clst_bfname = 'ur' # file name is clst_bfname_<vtaxid>_<mlen>.seq for UR and .clst for clusters

# starcode command
str_exe = '~/work/mystuff/tools/starcode/starcode'
#str_flags = ' -r 1 --print-clusters'   # message-passing algorithm
str_flags = ' -s --print-clusters'   # sphere algorithm

base_path = '/Users/yoramzarai/work/school/Simulation/Viruses/VUR/viruses/'
dtype_rnd = {'vtaxid':int, 'num_cds':int, 'signf_common':str, 'signf_F1':str, 'signf_F2':str, 'signf_F3':str}
backg = {'A':0.25,'C':0.25,'G':0.25,'T':0.25}  # background for PSSM 
base_save_file = '' # 'v_most_URs_diff' code appends '.png' to save the figure and '.txt' to save the prints. 
                    #  Set to '' to disable 
# =============================================================================================================
mmlens = ['m'+str(m) for m in mlens]

# handle for text file or sys.stdout
ftxt = open(base_save_file+'.txt', 'wt') if base_save_file!='' else sys.stdout

bfdata = os.path.join(clst_path, clst_bfname)
base_command = str_exe + str_flags

'''keys are (vtaxid, mlen), and values are dictionaries containing
clusters information (where keys are the centroids and values are the corresponding
cluster's sequences)'''
ur_clst_info = OrderedDict()
for j, mlen in enumerate(mlens):
    rnd_model = 'dnt_samp' if mlen==3 else 'syn_perm+dnt_samp'
    mmlen = mmlens[j]
    xlsx_file = os.path.join(base_path, mmlens[j], rnd_model, 'Results', 'vsignf'+'_'+rnd_model+'_'+mmlens[j]+'.xlsx')
    df_vrnd = pd.read_excel(xlsx_file, header=0, dtype=dtype_rnd)
    vtaxids = df_vrnd.loc[:, 'vtaxid']  # vtaxid Series
    # find the vtaxids with the most common URs
    sgf = df_vrnd.loc[:,'signf_common']  # all common URs per vtaxid
    tmp = sgf.apply(lambda x:len(x.split('|'))) # this works on the values of sgf (which are the URs)
    srt_tmp = tmp.sort_values(ascending=False)
    for i in range(num_tst_vtaxids):
        indx = srt_tmp.index[i]  # vtaxid index in srt_tmp
        vtaxid = vtaxids.iloc[indx]
        ur = df_vrnd.iloc[indx]['signf_common'].split('|')
        eql_nt = {s for s in ur if len(set(s))==1}  # URs with the same nucleotides (e.g., AAAA)
        gc_nt = {s for s in ur if re.search('[CG]{'+str(mlen)+'}',s)}  # URs that contain only G and/or C
        at_nt = {s for s in ur if re.search('[AT]{'+str(mlen)+'}',s)}  # URs that contain only A and/or T
        
        # CHOOSE here what is proc_nt (the URs to show logos)
        #proc_nt = set(ur)-eql_nt # all UR other than the ones with equal NT
        proc_nt = set(ur)
        #proc_nt = gc_nt
        #proc_nt = at_nt
        print('{}:\n\teql={} \n\tgc={}\n\tat={}\n\tproc={}'.format(vtaxid, eql_nt, gc_nt, at_nt, proc_nt), file=ftxt)
        if proc_nt and list(proc_nt)[0]!='nan':  # 'nan' is generated by pd.read_excel for empty cells
            _, _, _, m, _ = mysl.compute_pssm(proc_nt, backg, backg)
            rel_info = mysl.calc_rel_info(m, 'no')
            
            # clustering
            infile = '_'.join([bfdata, str(vtaxid), str(mlen)]) + '.seq'
            outfile = re.sub('.seq', '.clst', infile)
            myut.seq2plain_text_file(proc_nt, infile)
            ret, sout = subprocess.getstatusoutput(base_command+' -i ' + infile  + ' -o ' + outfile)
            #print(sout)
            if ret == 0:
                # parse starcode output
                clusters = mycl.parse_starcode_cls_out(outfile)
                #print('Found {} clusters:'.format(len(clusters)))
                #for k in clusters.keys(): print(clusters[k])
                ur_clst_info[(vtaxid, mlen)]=clusters
            else:
                print('starcode errored and returned: ', sout)
# Out:
# 1605721:
# 	eql={'CCC'}
# 	gc={'CCC'}
# 	at={'ATT'}
# 	proc={'CAC', 'GAA', 'CTG', 'GCT', 'GTT', 'GGA', 'CCC', 'ATT', 'TTC', 'AGC', 'TCC', 'TGA'}
# 1273750:
# 	eql={'AAA'}
# 	gc={'CGC', 'CCG'}
# 	at={'AAA'}
# 	proc={'GAC', 'TTG', 'CAA', 'CTA', 'CCG', 'CTC', 'GTC', 'AGA', 'CGC', 'GAG', 'AAA', 'CAT'}
# 1079999:
# 	eql={'TTT', 'AAA'}
# 	gc={'GCC', 'GGC'}
# 	at={'TTT', 'AAT', 'AAA'}
# 	proc={'GGC', 'AAT', 'GCT', 'TTT', 'ACA', 'GCC', 'GTC', 'CTC', 'TGT', 'AAA'}
# 1141526:
# 	eql={'TTT', 'AAA'}
# 	gc=set()
# 	at={'TTT', 'AAA'}
# 	proc={'CAC', 'GGA', 'GAT', 'CTA', 'TTT', 'CCA', 'GTG', 'CTC', 'GAG', 'AAA'}
# 268746:
# 	eql={'GGG', 'TTT', 'AAA'}
# 	gc={'GCC', 'GGG'}
# 	at={'TTT', 'AAT', 'AAA'}
# 	proc={'GGG', 'AAT', 'GCT', 'TTT', 'ACA', 'GCC', 'GTC', 'TGT', 'AAA'}
# 1029988:
# 	eql={'TTT'}
# 	gc={'GCC'}
# 	at={'TTT'}
# 	proc={'GAC', 'GGA', 'TTG', 'TAG', 'CAA', 'TTT', 'ACA', 'GCC', 'GAG'}
# 1195085:
# 	eql={'TTT'}
# 	gc=set()
# 	at={'TTT'}
# 	proc={'GAC', 'GGA', 'TTG', 'TAG', 'CAA', 'TTT', 'ACA', 'TGT', 'GAG'}
# 1283071:
# 	eql={'TTT', 'AAA'}
# 	gc={'GGC'}
# 	at={'TTT', 'AAA'}
# 	proc={'GGC', 'GAC', 'GGA', 'AGG', 'TTT', 'ACA', 'TGT', 'GAG', 'AAA'}
# 1604356:
# 	eql={'TTT', 'AAA'}
# 	gc={'GCG', 'CGC'}
# 	at={'TTT', 'AAA'}
# 	proc={'TTG', 'TGT', 'TAG', 'GCG', 'TTT', 'ACA', 'CGC', 'GAG', 'AAA'}
# 347325:
# 	eql={'TTT', 'AAA'}
# 	gc=set()
# 	at={'TTT', 'AAA'}
# 	proc={'CAC', 'GAT', 'TAG', 'CTA', 'TTT', 'GTG', 'CTC', 'GAG', 'AAA'}
# /Users/yoramzarai/work/school/Simulation/Viruses/vir_stat_jupyter/myseq_logo.py:102: RuntimeWarning: divide by zero encountered in log2
#   return [Hg+sum([pwm[b][l]*np.nan_to_num(np.log2(pwm[b][l])) for b in bases])\
# 1273750:
# 	eql={'GGGG'}
# 	gc={'CGCG', 'GGGG', 'GCGC'}
# 	at=set()
# 	proc={'ACTC', 'AGCT', 'CTCC', 'GCTC', 'CTCA', 'CATG', 'GGTC', 'AGAG', 'GTAC', 'GTCC', 'GGAC', 'GGGG', 'GACG', 'GAGT', 'GCAA', 'GACC', 'GTCA', 'GCGC', 'GAGA', 'CAAG', 'CAAC', 'CGCG', 'GAGC', 'GGAG'}
# 1605721:
# 	eql={'GGGG', 'CCCC'}
# 	gc={'GGGG', 'CCCC'}
# 	at=set()
# 	proc={'AAGC', 'AGCT', 'GGGA', 'CTTC', 'CTCC', 'GAAG', 'TCCG', 'TCAG', 'GGAA', 'GTTC', 'CTTA', 'AACG', 'CTGA', 'ACGT', 'CCCC', 'CGGA', 'GCTT', 'GGGG', 'CGTT', 'GTTA', 'AGCC', 'GGAG', 'TTCG'}
# 929832:
# 	eql={'AAAA', 'TTTT'}
# 	gc={'GCCG', 'GGCC', 'CGGC', 'CGCG', 'CCGG', 'GCGC'}
# 	at={'AAAA', 'AAAT', 'TTTT'}
# 	proc={'GCCG', 'AGCT', 'GGCC', 'TTTT', 'CGGC', 'AGCC', 'TTCA', 'GGCT', 'AGGC', 'CGCG', 'TCAA', 'CCGG', 'GCGC', 'AAAA', 'AAAT'}
# 445700:
# 	eql={'TTTT'}
# 	gc={'CGGC', 'CCGG', 'GGCC', 'GCGC'}
# 	at={'AAAT', 'TTTT'}
# 	proc={'TTTC', 'GGCC', 'AGCT', 'TCGA', 'CGGC', 'GCTT', 'AGCC', 'TTTT', 'GGCT', 'GCTC', 'CCGG', 'GTAC', 'GCGC', 'AAAT'}
# 444878:
# 	eql={'AAAA', 'TTTT'}
# 	gc={'CCGG', 'GCCC', 'GGCC'}
# 	at={'AAAA', 'AAAT', 'TTTT'}
# 	proc={'AGCT', 'GGCC', 'TCGA', 'GCTT', 'TTTT', 'AGCC', 'GGCT', 'GCCC', 'GCTA', 'CCGG', 'GTAC', 'ACGT', 'AAAA', 'AAAT'}
# 1273748:
# 	eql={'GGGG', 'CCCC'}
# 	gc={'GGGG', 'GGCC', 'CCCC'}
# 	at=set()
# 	proc={'AGCT', 'GGCC', 'GATC', 'AGCC', 'GGGG', 'GGCT', 'CATT', 'CTTG', 'CTAG', 'AATG', 'CCAA', 'ATGT', 'AGGG', 'CCCC'}
# 889956:
# 	eql={'AAAA', 'TTTT'}
# 	gc={'GCCG', 'CCGG', 'GGCC', 'GCGC'}
# 	at={'AAAA', 'AAAT', 'TTTT'}
# 	proc={'GCCG', 'TTTC', 'GGCC', 'AGCT', 'TCGA', 'GCTT', 'TTTT', 'AGCC', 'GGCT', 'CCGG', 'GTAC', 'GCGC', 'AAAA', 'AAAT'}
# 1283076:
# 	eql={'AAAA', 'TTTT'}
# 	gc={'GGCC'}
# 	at={'AATT', 'AAAA', 'TTTT'}
# 	proc={'AGCT', 'GGCC', 'AATT', 'TGGA', 'TCGA', 'TTTT', 'GATC', 'AGCC', 'GGCT', 'TCGG', 'GCTA', 'CCGA', 'ACGT', 'AAAA'}
# 268746:
# 	eql={'AAAA', 'TTTT'}
# 	gc={'CGCG', 'CCGG', 'GGCC', 'GCGC'}
# 	at={'AATT', 'AAAA', 'TTTT'}
# 	proc={'CATG', 'GGCC', 'AGCT', 'AATT', 'TCGA', 'TTTT', 'AGTC', 'AGCC', 'GGCT', 'CGCG', 'CCGG', 'GTAC', 'GCGC', 'AAAA'}
# 445696:
# 	eql={'AAAA', 'TTTT'}
# 	gc={'GCCG', 'GGCC', 'CGGC', 'CCGG', 'GCGC'}
# 	at={'AAAA', 'TTTT'}
# 	proc={'GCCG', 'TTTC', 'GGCC', 'AGCT', 'TCGA', 'CGGC', 'TTTT', 'AGCC', 'GGCT', 'GCTC', 'CCGG', 'GCGC', 'AAAA'}
# 1605721:
# 	eql={'CCCCC', 'GGGGG'}
# 	gc={'GGGGG', 'GGGGC', 'CGGGG', 'CCCCC', 'CCCGC', 'GCCCC', 'CCCCG'}
# 	at=set()
# 	proc={'GGAAC', 'CGAAG', 'CCCCT', 'GAAGC', 'GTTAA', 'CCCCG', 'GGAAT', 'GCTTA', 'GCTTG', 'CCTTC', 'GCTGA', 'GAAGG', 'GAACG', 'CCCGC', 'AACGC', 'CTCAG', 'GCGAA', 'AGTTC', 'GAAAC', 'ACTTA', 'CTTAC', 'TCGGA', 'TGTTA', 'AACGG', 'CCCCC', 'ACGGA', 'GCTTC', 'GCGTT', 'GCTCC', 'TCAGC', 'TCTTC', 'TTCTG', 'GGAAG', 'CTTAA', 'GGTTA', 'ACTTC', 'GTTCT', 'TTCGC', 'AGCTG', 'CGTTA', 'AGCCC', 'TCAGT', 'GTTAT', 'CCGGA', 'CCTTA', 'TTCGT', 'TCGTT', 'CGTTC', 'AAACG', 'CAGCT', 'GCCCC', 'CTTAT', 'GTCAG', 'AGCTT', 'CGTTT', 'CGGGG', 'TTCGG', 'TCCCC', 'CTCCC', 'GTTCG', 'GGGGC', 'ACGAA', 'ACGTT', 'AGCTA', 'ACCCC', 'CCCAG', 'AAGCT', 'ACTCC', 'AGCTC', 'GGCTT', 'CTTCA', 'AACGT', 'TCCGC', 'AACGA', 'GAAGT', 'CGGAG', 'CGGAA', 'GAGCT', 'CTTCT', 'TTACT', 'GCGGA', 'CTTCC', 'GGAGT', 'CTTCG', 'GGGAA', 'GGGGA', 'GGGGG', 'TCTGA', 'CTCCG', 'GGACT', 'CCTGA', 'GTTAC'}
# 382359:
# 	eql={'TTTTT', 'AAAAA'}
# 	gc={'CCGGG', 'GGGCC'}
# 	at={'AAAAT', 'TTTTT', 'AAAAA'}
# 	proc={'GAACA', 'TTCGA', 'ACCGG', 'GGCTT', 'GGTAC', 'CCGGG', 'GGCTG', 'GTACT', 'GGAAC', 'GGGCT', 'GCTAC', 'AGAAC', 'GGCCT', 'GGGCC', 'GGTTC', 'AAAAT', 'AGCTT', 'GTACG', 'AGTAC', 'GTTCC', 'AGGCT', 'GTACA', 'GTTCT', 'GTTCA', 'GTTCG', 'AAGCC', 'TGTAC', 'GAACG', 'TGTTC', 'AGCTA', 'TTTTT', 'GGCTA', 'GGCTC', 'TGGCT', 'AAAAA', 'CCGGA', 'GAACT', 'AGGCC', 'GTACC', 'AGTTC', 'AAGCT'}
# 1079998:
# 	eql={'TTTTT', 'AAAAA'}
# 	gc={'GGCCC', 'GGGCC'}
# 	at={'TTTTT', 'AAAAA'}
# 	proc={'GAACA', 'TTCGA', 'GGCTT', 'GGTAC', 'GGCTG', 'GTACT', 'GGAAC', 'GGCCC', 'GGGCT', 'AGAAC', 'GGGCC', 'GGTTC', 'AGCTT', 'GAGCT', 'GTACG', 'AGTAC', 'GTTCC', 'AGGCT', 'GTACA', 'GTTCT', 'GTTCA', 'GTTCG', 'AAGCC', 'TGTAC', 'TGTTC', 'AGCTA', 'TTTTT', 'GGCTA', 'GGCTC', 'TGGCT', 'AAAAA', 'AGCCC', 'GAACT', 'AGGCC', 'GTACC', 'AGCCA', 'AGTTC', 'AAGCT'}
# 458639:
# 	eql={'TTTTT', 'AAAAA'}
# 	gc={'CCGCG', 'GCGCG', 'CGCGG', 'CGCGC'}
# 	at={'ATTTT', 'AAATT', 'AATTT', 'AAAAT', 'TTTTT', 'TTTTA', 'AAAAA'}
# 	proc={'ATTTT', 'GATCG', 'CCTCA', 'GGACC', 'GGATC', 'CCTGG', 'GGTCC', 'AGATC', 'CGCGA', 'TTTTC', 'CTTTT', 'GATCT', 'AAATT', 'GAATT', 'ACGCG', 'AATTT', 'AAAAT', 'GCGCG', 'GCCAG', 'CCGCG', 'CGCGT', 'TTTTA', 'CCAGA', 'GATCA', 'GAAAA', 'TTTTT', 'AAAAA', 'TCGCG', 'AAATG', 'CGCGG', 'CTGTG', 'CGATC', 'TCCAG', 'CTCAG', 'GTTTT', 'CGCGC', 'TCTGG', 'AATTC'}
# 1273750:
# 	eql={'GGGGG', 'AAAAA'}
# 	gc={'GGGGG', 'GCGCG', 'GGCGC', 'CCGCG', 'CGCGC'}
# 	at={'AAAAA'}
# 	proc={'GAATG', 'GGACC', 'GGTAC', 'AGCGC', 'GCGCA', 'AGGTC', 'AATGG', 'CAGCT', 'CGCGA', 'CATGG', 'GCAAG', 'GGACG', 'CCATG', 'CGGAG', 'GCGAG', 'GCGCG', 'GGAGC', 'CCGCG', 'GCGCT', 'TGCAA', 'GCATG', 'CCGTC', 'GAGCC', 'GGAGT', 'GACGG', 'GGCTC', 'GCTCG', 'AAAAA', 'GGGGG', 'TCGCG', 'GGAGG', 'CTGCG', 'GGACT', 'CGCGC', 'GGCGC', 'GGGAG', 'GGTCA'}
# 445683:
# 	eql={'TTTTT', 'AAAAA'}
# 	gc={'CCGGG', 'GGGCC'}
# 	at={'TTTAA', 'ATTAA', 'TTTTT', 'AAAAA'}
# 	proc={'TTCGA', 'ACCGG', 'GGCTT', 'GGCTG', 'CCGGG', 'GGGCT', 'TCGAC', 'CAGCT', 'GGCCT', 'GCTTC', 'GTTAA', 'TCCGG', 'GAATT', 'GGGCC', 'TTTAA', 'GCTTG', 'AGCTT', 'TCGAA', 'GAGCT', 'CTTAA', 'ATTAA', 'AGGCT', 'TCGAG', 'GAAAT', 'GGCCA', 'GCCTC', 'AGCTA', 'TTTTT', 'GGCTC', 'GGCTA', 'CGGCT', 'AAAAA', 'TGGCT', 'CCGGA', 'AGGCC', 'AGCCA', 'AAGCT'}
# 754037:
# 	eql={'TTTTT', 'AAAAA'}
# 	gc={'GGCCC', 'CCGGG', 'GGGCC'}
# 	at={'ATTTT', 'AAAAT', 'TTTTT', 'TTTTA', 'AAAAA'}
# 	proc={'ACCGG', 'GGCTT', 'ATTTT', 'GGCTG', 'CCGGG', 'GGCCC', 'GGGCT', 'ACCTC', 'GGCCT', 'TTTTC', 'TCCGG', 'CTTTT', 'GGGCC', 'GCTTA', 'AAAAT', 'AGCTT', 'GAGCT', 'GTACG', 'AGTAC', 'TTTTA', 'AGGCT', 'GCTCT', 'AAGCC', 'GCTCA', 'TTTTT', 'GGCTC', 'GGCTA', 'TGGCT', 'AAAAA', 'CCGGA', 'TTTCA', 'AGGCC', 'CTCAG', 'AGCCA', 'AAGCT', 'AGCTC'}
# 555387:
# 	eql={'TTTTT', 'AAAAA'}
# 	gc={'GGCCC', 'GGGCC'}
# 	at={'AAAAT', 'TTTTA', 'TTTTT', 'AAAAA'}
# 	proc={'GGCTT', 'GGCTG', 'GTACT', 'ACGTC', 'GGCCC', 'GGGCT', 'CAGCT', 'TTTTC', 'CTTTT', 'GGGCC', 'GACTC', 'GCTTA', 'AAAAT', 'AGCTT', 'TCGAA', 'GAGCT', 'GTACG', 'AGTAC', 'TTTTA', 'AGGCT', 'CAGCC', 'GCTTT', 'AAGCC', 'CTCGA', 'TTTTT', 'GGCTA', 'TGGCT', 'AAAAA', 'AGCCC', 'TTTCA', 'AGGCC', 'GTACC', 'AGCCA', 'AAGCT', 'AGCTC'}
# 445696:
# 	eql={'TTTTT', 'AAAAA'}
# 	gc=set()
# 	at={'ATTTT', 'TTTTT', 'AATTT', 'AAAAA'}
# 	proc={'ATTTT', 'GGCTT', 'GAGGC', 'GGCTG', 'CCAGC', 'GGGCT', 'AGCGC', 'GCGCA', 'CAGCT', 'TTTTC', 'GCTGG', 'CTTTT', 'TTTTG', 'AATTT', 'ATTTC', 'AGCTT', 'TCGAA', 'GAGCT', 'AGGCT', 'CAGCC', 'AAGCC', 'AGCTA', 'GAAAA', 'TTTTT', 'GGCTC', 'GGCTA', 'AAAAA', 'AGCCC', 'TTTCA', 'AGGCC', 'AATTG', 'AGCCA', 'AATTC', 'AAGCT', 'AGCTC'}
# 445700:
# 	eql={'TTTTT', 'AAAAA'}
# 	gc=set()
# 	at={'ATTTT', 'TTTTT', 'TTTTA', 'AAAAA'}
# 	proc={'ATTTT', 'GGCTT', 'GGTAC', 'GTACT', 'CCAGC', 'GGGCT', 'AGCGC', 'GCGCA', 'TCGAT', 'CAGCT', 'GCTGG', 'TGCGC', 'GCTTG', 'AGCTT', 'GTACG', 'AGTAC', 'TTTTA', 'AGGCT', 'GTACA', 'AGCCT', 'AAGCC', 'GAAAT', 'TGTAC', 'AGCTA', 'TTTTT', 'GGCTA', 'TGGCT', 'AAAAA', 'AGCCC', 'TTTCA', 'AGGCC', 'AATTG', 'GTACC', 'AAGCT', 'AGCTC'}

# %% [markdown]
# ## Displaying sequence logos of clusters data

# %%
# MAKE SURE THE CELL ABOVE RUNS FIRST !!!

# ur_clst_info contains clusters information
for k in ur_clst_info:
    print('clusters for {}:'.format(k))
    val = ur_clst_info[k]
    for i, kk in enumerate(val.keys()):
        print('  C{} ({} seq): {}'.format(i,len(val[kk]), val[kk]))
# Out:
# clusters for (1605721, 3):
#   C0 (8 seq): ['AGC', 'ATT', 'CAC', 'CCC', 'GCT', 'TCC', 'TGA', 'TTC']
#   C1 (2 seq): ['CTG', 'GTT']
#   C2 (2 seq): ['GAA', 'GGA']
# clusters for (1273750, 3):
#   C0 (10 seq): ['CTA', 'CTC', 'CAA', 'CCG', 'CGC', 'AAA', 'AGA', 'CAT', 'GTC', 'TTG']
#   C1 (2 seq): ['GAG', 'GAC']
# clusters for (1079999, 3):
#   C0 (7 seq): ['GCT', 'GCC', 'GGC', 'CTC', 'GTC', 'TGT', 'TTT']
#   C1 (3 seq): ['AAA', 'AAT', 'ACA']
# clusters for (1141526, 3):
#   C0 (8 seq): ['CTA', 'CCA', 'CTC', 'AAA', 'CAC', 'GGA', 'GTG', 'TTT']
#   C1 (2 seq): ['GAT', 'GAG']
# clusters for (268746, 3):
#   C0 (6 seq): ['GCT', 'GCC', 'GGG', 'GTC', 'TGT', 'TTT']
#   C1 (3 seq): ['AAA', 'AAT', 'ACA']
# clusters for (1029988, 3):
#   C0 (6 seq): ['GAC', 'GAG', 'GCC', 'ACA', 'CAA', 'GGA']
#   C1 (3 seq): ['TTG', 'TAG', 'TTT']
# clusters for (1195085, 3):
#   C0 (7 seq): ['TAG', 'GAG', 'TTG', 'CAA', 'GAC', 'TGT', 'TTT']
#   C1 (2 seq): ['GGA', 'ACA']
# clusters for (1283071, 3):
#   C0 (7 seq): ['GGA', 'GGC', 'GAC', 'GAG', 'AAA', 'ACA', 'AGG']
#   C1 (2 seq): ['TTT', 'TGT']
# clusters for (1604356, 3):
#   C0 (6 seq): ['TAG', 'GAG', 'TTG', 'GCG', 'TGT', 'TTT']
#   C1 (2 seq): ['ACA', 'AAA']
#   C2 (1 seq): ['CGC']
# clusters for (347325, 3):
#   C0 (6 seq): ['TAG', 'GAG', 'GTG', 'TTT', 'GAT', 'AAA']
#   C1 (3 seq): ['CTC', 'CAC', 'CTA']
# clusters for (1273750, 4):
#   C0 (14 seq): ['GACG', 'GACC', 'GAGA', 'GAGC', 'GAGT', 'AGAG', 'CATG', 'CGCG', 'GGAC', 'GGAG', 'GGGG', 'GTAC', 'GTCA', 'GTCC']
#   C1 (8 seq): ['GCTC', 'GGTC', 'GCGC', 'ACTC', 'CTCA', 'AGCT', 'GCAA', 'CTCC']
#   C2 (2 seq): ['CAAC', 'CAAG']
# clusters for (1605721, 4):
#   C0 (9 seq): ['CTTC', 'CTCC', 'CTTA', 'GTTC', 'GCTT', 'CCCC', 'CGTT', 'GTTA', 'TTCG']
#   C1 (6 seq): ['AACG', 'AAGC', 'ACGT', 'AGCC', 'AGCT', 'GAAG']
#   C2 (6 seq): ['CGGA', 'CTGA', 'GGGA', 'GGGG', 'GGAG', 'GGAA']
#   C3 (2 seq): ['TCAG', 'TCCG']
# clusters for (929832, 4):
#   C0 (9 seq): ['AGCC', 'AGCT', 'AGGC', 'GGCC', 'CGCG', 'CGGC', 'GCCG', 'GCGC', 'GGCT']
#   C1 (3 seq): ['TTCA', 'TCAA', 'TTTT']
#   C2 (2 seq): ['AAAT', 'AAAA']
#   C3 (1 seq): ['CCGG']
# clusters for (445700, 4):
#   C0 (8 seq): ['GCGC', 'GCTC', 'GCTT', 'GGCC', 'CCGG', 'CGGC', 'GTAC', 'TCGA']
#   C1 (4 seq): ['AGCT', 'AGCC', 'GGCT', 'AAAT']
#   C2 (2 seq): ['TTTC', 'TTTT']
# clusters for (444878, 4):
#   C0 (6 seq): ['AGCT', 'AGCC', 'GGCT', 'ACGT', 'GCTA', 'GCTT']
#   C1 (3 seq): ['GCCC', 'GGCC', 'GTAC']
#   C2 (2 seq): ['AAAA', 'AAAT']
#   C3 (2 seq): ['TCGA', 'CCGG']
#   C4 (1 seq): ['TTTT']
# clusters for (1273748, 4):
#   C0 (7 seq): ['GGCC', 'GGCT', 'AGCC', 'GATC', 'GGGG', 'CCCC', 'AGCT']
#   C1 (4 seq): ['AATG', 'AGGG', 'ATGT', 'CATT']
#   C2 (3 seq): ['CTAG', 'CTTG', 'CCAA']
# clusters for (889956, 4):
#   C0 (7 seq): ['GCGC', 'GCCG', 'GCTT', 'GGCC', 'CCGG', 'GTAC', 'TCGA']
#   C1 (3 seq): ['AGCT', 'AGCC', 'GGCT']
#   C2 (2 seq): ['AAAA', 'AAAT']
#   C3 (2 seq): ['TTTC', 'TTTT']
# clusters for (1283076, 4):
#   C0 (7 seq): ['AGCT', 'AGCC', 'GGCT', 'AATT', 'ACGT', 'GCTA', 'GGCC']
#   C1 (4 seq): ['CCGA', 'TCGA', 'TGGA', 'TCGG']
#   C2 (1 seq): ['AAAA']
#   C3 (1 seq): ['GATC']
#   C4 (1 seq): ['TTTT']
# clusters for (268746, 4):
#   C0 (8 seq): ['GGCC', 'AGCC', 'GGCT', 'CGCG', 'GCGC', 'AGCT', 'AGTC', 'GTAC']
#   C1 (4 seq): ['AATT', 'AAAA', 'TTTT', 'CATG']
#   C2 (2 seq): ['CCGG', 'TCGA']
# clusters for (445696, 4):
#   C0 (7 seq): ['GCGC', 'GCTC', 'GCCG', 'GGCC', 'CCGG', 'CGGC', 'TCGA']
#   C1 (3 seq): ['AGCT', 'AGCC', 'GGCT']
#   C2 (2 seq): ['TTTC', 'TTTT']
#   C3 (1 seq): ['AAAA']
# clusters for (1605721, 5):
#   C0 (24 seq): ['GCTTA', 'GCTGA', 'GCTTC', 'GCTTG', 'ACTTA', 'CCTTA', 'GGTTA', 'CGTTA', 'CTTAA', 'CTTAC', 'CTTAT', 'GCGAA', 'GCGTT', 'GCTCC', 'AGCTA', 'AGCTT', 'CCTGA', 'CCTTC', 'GGCTT', 'GTTAA', 'GTTAC', 'GTTAT', 'TCTTC', 'TGTTA']
#   C1 (15 seq): ['GGAAG', 'GGAAT', 'GGAAC', 'CGAAG', 'GGACT', 'GGAGT', 'GGGAA', 'GTCAG', 'CGGAG', 'GAAAC', 'GAACG', 'GAAGC', 'GAAGG', 'GAAGT', 'CGGAA']
#   C2 (14 seq): ['CTTCG', 'CTCCG', 'CTTCA', 'CTTCC', 'CTTCT', 'GTTCG', 'CTCAG', 'CTCCC', 'TTCTG', 'TTCGT', 'TTCGG', 'TTCGC', 'GTTCT', 'CCCCG']
#   C3 (9 seq): ['AGTTC', 'ACTTC', 'AGCTC', 'CGTTC', 'ACGTT', 'ACTCC', 'CGTTT', 'AGCCC', 'AGCTG']
#   C4 (9 seq): ['CCCGC', 'CCCCC', 'TCCGC', 'ACCCC', 'CCCAG', 'TCCCC', 'CCCCT', 'TCAGC', 'GCCCC']
#   C5 (8 seq): ['TCGGA', 'TCTGA', 'GCGGA', 'ACGGA', 'CCGGA', 'ACGAA', 'TCAGT', 'TCGTT']
#   C6 (5 seq): ['AACGT', 'AACGA', 'AACGC', 'AACGG', 'AAACG']
#   C7 (4 seq): ['GGGGC', 'GGGGA', 'GGGGG', 'CGGGG']
#   C8 (3 seq): ['GAGCT', 'AAGCT', 'CAGCT']
#   C9 (1 seq): ['TTACT']
# clusters for (382359, 5):
#   C0 (16 seq): ['GGCTC', 'GGCTA', 'GGCTG', 'GGCTT', 'GGTTC', 'GCTAC', 'GGCCT', 'GGGCC', 'GGGCT', 'GGTAC', 'AGCTA', 'AGCTT', 'AGGCC', 'AGTTC', 'TGGCT', 'TGTTC']
#   C1 (12 seq): ['GTACT', 'GTACA', 'GTACC', 'GTACG', 'GTTCT', 'GAACT', 'GTTCA', 'GTTCC', 'GTTCG', 'TGTAC', 'GAACA', 'GAACG']
#   C2 (5 seq): ['AGAAC', 'AGTAC', 'GGAAC', 'AAAAA', 'AAAAT']
#   C3 (3 seq): ['AAGCT', 'AAGCC', 'AGGCT']
#   C4 (3 seq): ['ACCGG', 'CCGGA', 'CCGGG']
#   C5 (1 seq): ['TTCGA']
#   C6 (1 seq): ['TTTTT']
# clusters for (1079998, 5):
#   C0 (14 seq): ['GGCTC', 'GGCCC', 'GGCTA', 'GGCTG', 'GGCTT', 'GGTTC', 'GGGCC', 'GGGCT', 'GGTAC', 'AGCTT', 'AGGCC', 'AGTTC', 'TGGCT', 'TGTTC']
#   C1 (11 seq): ['GTACC', 'GTACG', 'GTACT', 'GTTCC', 'GTACA', 'GTTCA', 'GTTCG', 'GTTCT', 'TGTAC', 'GAACT', 'GAACA']
#   C2 (4 seq): ['AAGCT', 'AAGCC', 'AGGCT', 'GAGCT']
#   C3 (4 seq): ['AGAAC', 'AGTAC', 'GGAAC', 'AAAAA']
#   C4 (3 seq): ['AGCCA', 'AGCCC', 'AGCTA']
#   C5 (1 seq): ['TTCGA']
#   C6 (1 seq): ['TTTTT']
# clusters for (458639, 5):
#   C0 (10 seq): ['AATTT', 'AAATT', 'AATTC', 'ATTTT', 'AAAAT', 'AAATG', 'CTTTT', 'GAATT', 'GATCT', 'GTTTT']
#   C1 (10 seq): ['CCGCG', 'ACGCG', 'GCGCG', 'TCGCG', 'CCTCA', 'CGCGA', 'CGCGC', 'CGCGG', 'CGCGT', 'CTGTG']
#   C2 (5 seq): ['AGATC', 'CGATC', 'GGATC', 'GATCG', 'GATCA']
#   C3 (4 seq): ['CTCAG', 'TCCAG', 'GCCAG', 'CCAGA']
#   C4 (3 seq): ['TTTTC', 'TTTTA', 'TTTTT']
#   C5 (2 seq): ['GAAAA', 'AAAAA']
#   C6 (2 seq): ['GGTCC', 'GGACC']
#   C7 (2 seq): ['TCTGG', 'CCTGG']
# clusters for (1273750, 5):
#   C0 (17 seq): ['GGACG', 'GGACC', 'GGACT', 'GGAGG', 'GAATG', 'GACGG', 'GCAAG', 'GCATG', 'GCGAG', 'GCTCG', 'CGGAG', 'GGAGC', 'GGAGT', 'GGGAG', 'GGGGG', 'GGTAC', 'GGTCA']
#   C1 (11 seq): ['CCGCG', 'CTGCG', 'GCGCG', 'TCGCG', 'CAGCT', 'CCATG', 'CCGTC', 'CGCGA', 'CGCGC', 'GCGCT', 'GCGCA']
#   C2 (5 seq): ['GGCTC', 'GGCGC', 'AGGTC', 'AGCGC', 'GAGCC']
#   C3 (2 seq): ['CATGG', 'AATGG']
#   C4 (1 seq): ['AAAAA']
#   C5 (1 seq): ['TGCAA']
# clusters for (445683, 5):
#   C0 (13 seq): ['AGGCT', 'AAGCT', 'AGGCC', 'CGGCT', 'GGGCT', 'TGGCT', 'AGCTA', 'AGCTT', 'CAGCT', 'GAGCT', 'GGCTG', 'GGCTT', 'GGGCC']
#   C1 (6 seq): ['TTTAA', 'GTTAA', 'CTTAA', 'ATTAA', 'TTCGA', 'TTTTT']
#   C2 (4 seq): ['GCCTC', 'GCTTC', 'GGCTC', 'GCTTG']
#   C3 (4 seq): ['GGCCA', 'GGCCT', 'GGCTA', 'AGCCA']
#   C4 (4 seq): ['TCCGG', 'ACCGG', 'CCGGG', 'CCGGA']
#   C5 (3 seq): ['GAAAT', 'GAATT', 'AAAAA']
#   C6 (3 seq): ['TCGAC', 'TCGAA', 'TCGAG']
# clusters for (754037, 5):
#   C0 (14 seq): ['AGCTC', 'ACCTC', 'AGCTT', 'GGCTC', 'AAGCC', 'AAGCT', 'AGCCA', 'AGGCC', 'AGGCT', 'AGTAC', 'GAGCT', 'GCTCT', 'GGCTA', 'GGCTG']
#   C1 (6 seq): ['GGCCT', 'GGCCC', 'GGCTT', 'GGGCT', 'TGGCT', 'GGGCC']
#   C2 (4 seq): ['ACCGG', 'TCCGG', 'CCGGG', 'CCGGA']
#   C3 (4 seq): ['ATTTT', 'CTTTT', 'TTTTT', 'TTTTC']
#   C4 (2 seq): ['AAAAT', 'AAAAA']
#   C5 (2 seq): ['GCTTA', 'GCTCA']
#   C6 (2 seq): ['TTTCA', 'TTTTA']
#   C7 (1 seq): ['CTCAG']
#   C8 (1 seq): ['GTACG']
# clusters for (555387, 5):
#   C0 (16 seq): ['AGCTC', 'AGCCC', 'AGCTT', 'AAGCC', 'AAGCT', 'ACGTC', 'AGCCA', 'AGGCC', 'AGTAC', 'CAGCC', 'CAGCT', 'GACTC', 'GGCCC', 'GGCTA', 'GGCTG', 'GGCTT']
#   C1 (5 seq): ['GGGCT', 'GGGCC', 'TGGCT', 'GAGCT', 'AGGCT']
#   C2 (4 seq): ['TTTTA', 'TTTCA', 'TTTTC', 'TTTTT']
#   C3 (3 seq): ['GCTTT', 'GCTTA', 'CTTTT']
#   C4 (3 seq): ['GTACC', 'GTACG', 'GTACT']
#   C5 (2 seq): ['AAAAT', 'AAAAA']
#   C6 (2 seq): ['CTCGA', 'TCGAA']
# clusters for (445696, 5):
#   C0 (16 seq): ['AGCTC', 'AGCCC', 'AGCGC', 'AGCTA', 'AGCTT', 'GGCTC', 'AAGCC', 'AAGCT', 'AATTC', 'AGCCA', 'AGGCC', 'CAGCC', 'CAGCT', 'GGCTA', 'GGCTG', 'GGCTT']
#   C1 (8 seq): ['ATTTT', 'ATTTC', 'CTTTT', 'AATTT', 'TTTTT', 'TTTTG', 'AATTG', 'TTTTC']
#   C2 (5 seq): ['GGGCT', 'AGGCT', 'GAGCT', 'GCGCA', 'GAGGC']
#   C3 (2 seq): ['GAAAA', 'AAAAA']
#   C4 (1 seq): ['CCAGC']
#   C5 (1 seq): ['GCTGG']
#   C6 (1 seq): ['TCGAA']
#   C7 (1 seq): ['TTTCA']
# clusters for (445700, 5):
#   C0 (14 seq): ['AGGCT', 'AAGCT', 'AGCCT', 'AGGCC', 'GGGCT', 'TGGCT', 'AAGCC', 'AGCCC', 'AGCTA', 'AGCTC', 'AGCTT', 'CAGCT', 'GGCTA', 'GGCTT']
#   C1 (7 seq): ['AGTAC', 'GGTAC', 'TGTAC', 'GTACT', 'GTACG', 'GTACC', 'GTACA']
#   C2 (3 seq): ['ATTTT', 'TTTTT', 'AATTG']
#   C3 (3 seq): ['TGCGC', 'AGCGC', 'GCGCA']
#   C4 (2 seq): ['GAAAT', 'AAAAA']
#   C5 (2 seq): ['GCTTG', 'GCTGG']
#   C6 (2 seq): ['TTTCA', 'TTTTA']
#   C7 (1 seq): ['CCAGC']
#   C8 (1 seq): ['TCGAT']
